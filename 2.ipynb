# %% [markdown]
# <a href="https://colab.research.google.com/github/kotatech24/AIML/blob/main/2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a+b
# Out:
# 30

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
x = True
y = False

# %%
x and y
# Out:
# False

# %%
x or y
# Out:
# True

# %%
not x
# Out:
# False

# %%
not y
# Out:
# True

# %%
n = 10

# %%
n += 5 # n = n + 5
print(n)
# Out:
# 15

# %%
n -= 6  # n = n - 6
print(n)
# Out:
# 9

# %%
n *= 5   # n = n * 5
print(n)
# Out:
# 45

# %%
# n = n/5
n /= 5
print(n)
# Out:
# 9.0

# %%
x = input("what is your name")
# Out:
# what is your namesrinivas

# %%
print(f"welcome to the training {x}")
# Out:
# welcome to the training srinivas

# %%
y = input("enter your age")
print(y)
# Out:
# enter your age12
# 12

# %%
y = int(input("enter your age"))
print(y)
# Out:
# enter your age23
# 23

# %%
result = 10 + 2 * 3
result
# Out:
# 16

# %%
result = (10 + 2) * 3
result
# Out:
# 36

# %%
result = 2 ** 3 ** 2 # right to left exponentiation
# 2 ** (3 ** 2)
result
# Out:
# 512

# %%
x = int(input ("enter the value"))
if x > 10:
    print("The value is more then 10")
else:
    print("the value is less then 10 ")
# Out:
# enter the value12
# The value is more then 10

# %%
num = int(input("enter the value"))
if num > 0:
    print("It is a positive value")
elif num == 0:
    print("the value of num is zero")
else:
    print("it is a negative value")
# Out:
# enter the value12
# It is a positive value

# %%
# check if a number is even or odd
num = int(input("enter the value"))
if num%2 == 0:
    print("the number is even")

else:
    print("the number is odd")
# Out:
# enter the value12
# the number is even

# %%
# write a function to print hello world
def greeting():
    print("hello world")

greeting()
# Out:
# hello world

# %%
def add(a,b):
    return a + b

print(add(10,5))
# Out:
# 15

# %%
def add(a,b):
     a + b

print(add(10,5))
# Out:
# None

# %%
def evenorodd(a):
   if a%2 == 0:
       return  "Even"
   else:
        return "Odd"

x = evenorodd(int(input("enter a value")))
print(f"We have the value {x}")
# Out:
# enter a value12
# We have the value Even

# %%
def emailvalid(x):
    if "@" in x and "." in x:
        return "valid email"
    else:
        return "invalid email"

print(emailvalid("akshatawsac@gmailcom"))
# Out:
# invalid email

# %%
#%% md
List in python is ordered mutable collection of elements
numbers = [10, 20, 30, 40, 50]
number[0] =10
number[1] = 20
number[2] = 30
and so on
my_list = []
# Out:
#   File "/tmp/ipykernel_2043/1527976372.py", line 2
#     List in python is ordered mutable collection of elements
#                               ^
# SyntaxError: invalid syntax

# %%
a = [10, 20, 30, 40]
print(a[0])
print(a[1])
print(a[2])
# Out:
# 10
# 20
# 30

# %%
for x in a:
    print(x)
# Out:
# 10
# 20
# 30
# 40

# %%
my_list = []
my_list.append(10)
print(my_list)
my_list.append(20)
print(my_list)
my_list.append(23)
print(my_list)
# Out:
# [10]
# [10, 20]
# [10, 20, 23]

# %%
num1 = [1, 2]
num1.extend([3, 4, 5])
print(num1)
# Out:
# [1, 2, 3, 4, 5]

# %%
#insert element at specific position
num = [1,2]
num.insert(1,"python")
print(num)
# Out:
# [1, 'python', 2]

# %%
# remove the first occurence of 3 in the list
num = [1, 2, 3, 4, 3]
num.remove(3)
print(num)
# Out:
# [1, 2, 4, 3]

# %%
# delete last element
num = [1, 2, 3, 4]
print(num)
num.pop()
print(num)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]

# %%
#clear all the elements
num = [1, 2, 3, 4]
print(num)
num.clear()
print(num)
# Out:
# [1, 2, 3, 4]
# []

# %%
# find the index of the element
num = [10, 21, 31, 42]
# num[0] = 10
#num[1] = 21
#num[2] = 31
print(num.index(31))
# Out:
# 2

# %%
#How to find index of last occurance and
#delete the last occurance of number?

# %%
#How to remove duplicate values of a list?

a = [10, 20, 30, 40, 50, 50, 50]
a = list(set(a))
print(a)
# Out:
# [40, 10, 50, 20, 30]

# %%
#How to reverse the list?
a = [10, 20, 34]
a.reverse()
print(a)
# Out:
# [34, 20, 10]

# %%
#Think of loop as a repetition with rules

without loops:

print("hello")
print("hello")
print("hello")

#with loop:
for i in range(3):
   print("hello")
# Out:
#   File "/tmp/ipykernel_2043/1162281266.py", line 3
#     without loops:
#             ^
# SyntaxError: invalid syntax

# %%
#call roll 1 to 5
for roll in range(1,6):
    print(f"Roll number: {roll}")
# Out:
# Roll number: 1
# Roll number: 2
# Roll number: 3
# Roll number: 4
# Roll number: 5

# %%
fruits = ["apple", "banana", "orange"]
for x in fruits:
    print(f"Fruits are {x}")
# Out:
# Fruits are apple
# Fruits are banana
# Fruits are orange

# %%
# fill the water until bucket is full
water = 0
while water < 5:
    print("filling water....")
    water = water + 1
# Out:
# filling water....
# filling water....
# filling water....
# filling water....
# filling water....

# %%
# print the even numbers from 1 to 20
for i in range(1,21):
    if i%2 == 0:
        print(f"Even number {i}")
    else:
        print(f"Not even {i}")
# Out:
# Not even 1
# Even number 2
# Not even 3
# Even number 4
# Not even 5
# Even number 6
# Not even 7
# Even number 8
# Not even 9
# Even number 10
# Not even 11
# Even number 12
# Not even 13
# Even number 14
# Not even 15
# Even number 16
# Not even 17
# Even number 18
# Not even 19
# Even number 20

# %%
# print each character in a string
text = "helloworld"
for x in text:
    print(x)
# Out:
# h
# e
# l
# l
# o
# w
# o
# r
# l
# d

# %%
# count the characters in the string
text = "helloworld"
count = 0
for ch in text:
    count = count + 1
print(count)
# Out:
# 10

# %%
# count the vowels in the string
text = "education"
vowels = "aeiou"
count = 0
for ch in text:
    print(ch)   # print the text as characters
    if ch in vowels:
        count = count + 1
print(f"vowels count {count}")
# Out:
# e
# d
# u
# c
# a
# t
# i
# o
# n
# vowels count 5

# %%
##%% mdString is a sequence of characters enclosed in a single(') or double (") quotes

# %%
name = "akshat"
greeting = 'hello'
print(name)
print(greeting)
# Out:
# akshat
# hello

# %%
message = """ this is
a multiline
string"""

print(message)
# Out:
#  this is
# a multiline
# string

# %%
text = "python"
print(text[0])
print(text[1])

print(text[-1])
# Out:
# p
# y
# n

# %%
text = "AKSHAT IS HUMAN"
# change to lower case
print(text.lower())
# Out:
# akshat is human

# %%
name = "Akshat"
# change to capital letter
print(name.upper())
# Out:
# AKSHAT

# %%
name = "    hi     "
cleaned_name =  name.strip()
print(cleaned_name)
# Out:
# hi

# %%
print(name)
# Out:
#     hi

# %%
cleaned_name
# Out:
# 'hi'

# %%
name = "akshat is your trainer"
# i want to split this string like [akshat, is , your, trainer]
print(name.split())
# Out:
# ['akshat', 'is', 'your', 'trainer']

# %%
text = "we are learning java"
# replace java with python
print(text.replace("java", "python"))
# Out:
# we are learning python

# %%
dte = ["2025", "12", "13"]
# i need to have this list in the date format
date = "-".join(dte)
print(date)
# Out:
# 2025-12-13

# %%
# find a word position
sentence = "python is a coding laguage"
print(sentence.find("is"))
#find: returns index of first occurrence
# Out:
# 7

# %%
# count how many times "a" appears
sentence = "hello akshat we are good and we eat apple"
print(sentence.count("a"))  # print 4
print(f"count of a is {sentence.count("a")}")   # count of a is 6

# if you put f literal in the print statement then
# you can just pass a variable in "" only
# for example: print(f"the value of the variable is {x}")
# w/o f : print("the value of the variable is", x)

print("count of a is ", sentence.count("a"))  #count of a is 6
# Out:
# 6
# count of a is 6
# count of a is  6

# %%
# check starting and ending words
a = "hello world"
print(a[0])
print(a[-1])
# Out:
# h
# d

# %%
# check if the string starts with word "hello"  and end with world
b = "hello akshat"
print(f"starts with hello: {b.startswith("hello")}")
print(f"starts with world: {b.endswith("world")}")
# Out:
# starts with hello: True
# starts with world: False

# %%
# how to find the first and last word in the sentence
sentence = "python is a very easy langauge to learn"
words = sentence.split()
print(words)
print(words[0])
print(words[1])
print(words[2])
print(words[-1])
# Out:
# ['python', 'is', 'a', 'very', 'easy', 'langauge', 'to', 'learn']
# python
# is
# a
# learn

# %%
##Tuple : It is like list but elements are immutable .
#Tuple : It is like list but elements are immutable .
#Fast then list
#list = [1, 2, 3]
#tuple = (1, 2, 3)

# %%
my_tuple = (10,20,30,40)
print(my_tuple)
# Out:
# (10, 20, 30, 40)

# %%
print(my_tuple[0])
# Out:
# 10

# %%
print(my_tuple[1])
# Out:
# 20

# %%
x = [1,2,3]
print(x)
x[0] = 30
print(x)
# Out:
# [1, 2, 3]
# [30, 2, 3]

# %%
x = (1,2,3)
print(x)
x[0] = 12
print(x)  # error because tuple elements are immutable
# Out:
# (1, 2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2043/2909863232.py in <cell line: 0>()
#       1 x = (1,2,3)
#       2 print(x)
# ----> 3 x[0] = 12
#       4 print(x)  # error because tuple elements are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
##String is a sequence of characters enclosed in a single(') or double (") quotes

# %%
name = "akshat"
greeting = 'hello'
print(name)
print(greeting)
# Out:
# akshat
# hello

# %%
message = """ this is
a multiline
string"""

print(message)
# Out:
#  this is
# a multiline
# string

# %%
text = "python"
print(text[0])
print(text[1])

print(text[-1])
# Out:
# p
# y
# n

# %%
text = "AKSHAT IS HUMAN"
# change to lower case
print(text.lower())
# Out:
# akshat is human

# %%
name = "Akshat"
# change to capital letter
print(name.upper())
# Out:
# AKSHAT

# %%
name = "    hi     "
cleaned_name =  name.strip()
print(cleaned_name)
# Out:
# hi

# %%
print(name)
# Out:
#     hi

# %%
cleaned_name
# Out:
# 'hi'

# %%
name = "akshat is your trainer"
# i want to split this string like [akshat, is , your, trainer]
print(name.split())
# Out:
# ['akshat', 'is', 'your', 'trainer']

# %%
text = "we are learning java"
# replace java with python
print(text.replace("java", "python"))
# Out:
# we are learning python

# %%
dte = ["2025", "12", "13"]
# i need to have this list in the date format
date = "-".join(dte)
print(date)
# Out:
# 2025-12-13

# %%
# find a word position
sentence = "python is a coding laguage"
print(sentence.find("is"))
#find: returns index of first occurrence
# Out:
# 7

# %%
# count how many times "a" appears
sentence = "hello akshat we are good and we eat apple"
print(sentence.count("a"))  # print 4
print(f"count of a is {sentence.count("a")}")   # count of a is 6

# if you put f literal in the print statement then
# you can just pass a variable in "" only
# for example: print(f"the value of the variable is {x}")
# w/o f : print("the value of the variable is", x)

print("count of a is ", sentence.count("a"))  #count of a is 6
# Out:
# 6
# count of a is 6
# count of a is  6

# %%
# check starting and ending words
a = "hello world"
print(a[0])
print(a[-1])
# Out:
# h
# d

# %%
# check if the string starts with word "hello"  and end with world
b = "hello akshat"
print(f"starts with hello: {b.startswith("hello")}")
print(f"starts with world: {b.endswith("world")}")
# Out:
# starts with hello: True
# starts with world: False

# %%
# how to find the first and last word in the sentence
sentence = "python is a very easy langauge to learn"
words = sentence.split()
print(words)
print(words[0])
print(words[1])
print(words[2])
print(words[-1])
# Out:
# ['python', 'is', 'a', 'very', 'easy', 'langauge', 'to', 'learn']
# python
# is
# a
# learn
