# %% [markdown]
# <a href="https://colab.research.google.com/github/kotatech24/AIML/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file=open("sample.txt","w") #We are creating a file sample.txt and open in it write mode
file.write(" This is line one  \n")
file.write("     This is line two\n")
file.write("This is line three")
file.close()

# %%
print("Hello")
# Out:
# Hello

# %%
file=open("sample.txt","r") #We are creating a file sample.txt and open in it write mode
content =file.read() # This is reading all the content in one go
print(content)
file.close()
# Out:
#  This is line one
#      This is line two
# This is line three

# %%
file=open("sample.txt","r") #We are creating a file sample.txt and open in it write mode
for line in file:
  print(line.strip()) # Strip is using to remove leading and trailing spaces
file.close()
# Out:
# This is line one
# This is line two
# This is line three

# %%
with open("sample.txt","r") as file: #We are creating a file sample.txt and open in it write mode
#  content =file.read() # This is reading all the content in one go
  for line in file:
    print(line.strip())
# Out:
# This is line one
# This is line two
# This is line three
