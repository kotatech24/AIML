# %% [markdown]
# <a href="https://colab.research.google.com/github/kotatech24/AIML/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.chunk import RegexpParser
from nltk import word_tokenize, pos_tag

# %%
text = "The big red car is parked outside the house"
tokens = word_tokenize(text)
tokens
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipykernel_1676/3231463186.py in <cell line: 0>()
#       1 text = "The big red car is parked outside the house"
# ----> 2 tokens = word_tokenize(text)
#       3 tokens
#
# /usr/local/lib/python3.13/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.13/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
# ...

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
pos_tags = pos_tag(tokens)
pos_tags
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1676/1350898625.py in <cell line: 0>()
# ----> 1 pos_tags = pos_tag(tokens)
#       2 pos_tags
#
# NameError: name 'tokens' is not defined

# %%
The big red car

The - DT
big - JJ
red - JJ
car - NN

<DT>? - ? means single occurance or no occurance - this will search The
<JJ>* - * means 0 or more orrurances - big red
<NN> - car

grammar => {<DT>?<JJ>*<NN>} = this is a example of Noun Phrase
grammar => {<VB.*><NP|PP>*} = this is a example of verb phrase
grammar => {<IN><NP>} = preposition phrase
Beautiful car

is valid grammar

<DT> - nothing - it is ok
<JJ> - Beautiful - ok
<NN> - car - ok


The car is fast
this sentence is not fitting into my grammar
<DT> -  The
<JJ> - Fast
<NN> - No NN
# Out:
#   File "/tmp/ipykernel_1676/523311325.py", line 1
#     The big red car
#         ^
# SyntaxError: invalid syntax

# %%
P  - noun phrase



grammar = "NP: {<DT>?<JJ>*<NN>}"
chunk_parser = RegexpParser(grammar)
tree = chunk_parser.parse(pos_tags)
print(tree)
tree.draw()
# Out:
#   File "/tmp/ipykernel_1676/1604627649.py", line 1
#     P  - noun phrase
#               ^
# SyntaxError: invalid syntax

# %%
print("Hi")
# Out:
# Hi

# %%
# !pip install nltk

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1676/1462503502.py in <cell line: 0>()
#       1 import nltk
# ----> 2 nltk.download()
#
# /usr/local/lib/python3.13/dist-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     758             if download_dir is not None:
#     759                 self._download_dir = download_dir
# --> 760             self._interactive_download()
#     761             return True
#     762
#
# /usr/local/lib/python3.13/dist-packages/nltk/downloader.py in _interactive_download(self)
# ...

# %%
import nltk
nltk.download('all-nltk', quiet=True)
# Out:
# True

# %%
import nltk
from nltk.corpus import gutenberg
print(gutenberg.fileids())
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
import nltk
from nltk.chunk import RegexpParser
from nltk import word_tokenize, pos_tag

# %%
text ="The big red car is parked outside the house"
tokens = word_tokenize(text)
tags=pos_tag(tokens)
tokens
tags
# Out:
# [('The', 'DT'),
#  ('big', 'JJ'),
#  ('red', 'JJ'),
#  ('car', 'NN'),
#  ('is', 'VBZ'),
#  ('parked', 'VBN'),
#  ('outside', 'IN'),
#  ('the', 'DT'),
#  ('house', 'NN')]

# %%
grammer = "NP : {<DT>?<JJ>*<NN>}"
chunk_parser = RegexpParser(grammer)
tree = chunk_parser.parse(tags)
tree.draw()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_1676/3534424545.py in <cell line: 0>()
#       2 chunk_parser = RegexpParser(grammer)
#       3 tree = chunk_parser.parse(tags)
# ----> 4 tree.draw()
#
# /usr/local/lib/python3.13/dist-packages/nltk/tree/tree.py in draw(self)
#     759         from nltk.draw.tree import draw_trees
#     760
# --> 761         draw_trees(self)
#     762
#     763     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /usr/local/lib/python3.13/dist-packages/nltk/draw/tree.py in draw_trees(*trees)
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#    1010
#
# /usr/local/lib/python3.13/dist-packages/nltk/draw/tree.py in __init__(self, *trees)
#     857         self._trees = trees
#     858
# --> 859         self._top = Tk()
# ...

# %%
text = '''
The quick brown fox jumps over the lazy dog.
The young studen from Delhi won the science competition for $10000.
'''

#tokenization
#pos_tagging
#lammatization
#ner
#define chunck grammer for  NP - Noune Pharase, PP (Proposition Phrase), VP (Verb phrase)
#Create chunk parser
#apply chuncking
#display chunck clearly
#display tree structure

# %%
The big red car

The - DT
big - JJ
red - JJ
car - NN

<DT>? - ? means single occurance or no occurance - this will search The
<JJ>* - * means 0 or more orrurances - big red
<NN> - car

grammar => {<DT>?<JJ>*<NN>} = this is a example of Noun Phrase
grammar => {<VB.*><NP|PP>*} = this is a example of verb phrase
grammar => {<IN><NP>} = preposition phrase
Beautiful car

is valid grammar

<DT> - nothing - it is ok
<JJ> - Beautiful - ok
<NN> - car - ok


The car is fast
this sentence is not fitting into my grammar
<DT> -  The
<JJ> - Fast
<NN> - No NN
#%%
# Out:
#   File "/tmp/ipykernel_1676/415049368.py", line 1
#     The big red car
#         ^
# SyntaxError: invalid syntax

# %%
tokens = word_tokenize(text)
tags=pos_tag(tokens)
tags
# Out:
# [('The', 'DT'),
#  ('quick', 'JJ'),
#  ('brown', 'NN'),
#  ('fox', 'NN'),
#  ('jumps', 'VBZ'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('lazy', 'JJ'),
#  ('dog', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('young', 'JJ'),
#  ('studen', 'NN'),
#  ('from', 'IN'),
#  ('Delhi', 'NNP'),
#  ('won', 'VBD'),
#  ('the', 'DT'),
#  ('science', 'NN'),
#  ('competition', 'NN'),
#  ('for', 'IN'),
#  ('$', '$'),
#  ('10000', 'CD'),
#  ('.', '.')]

# %%
# !pip install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 4.9 MB/s eta 0:00:00
# ...

# %%
#%%
##IMRAN

import nltk
from nltk import word_tokenize, pos_tag, ne_chunk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')

from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

import spacy

nltk.download('wordnet')

def get_stop_words(tokens):
  stop_words = set(stopwords.words('english'))
  stop_words.update(['.','$'])
  filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
  return filtered_tokens




def get_wordnet_pos(tag):
  if tag.startswith('J'):
    return wordnet.ADJ
  elif tag.startswith('V'):
    return wordnet.VERB
  elif tag.startswith('N'):
    return wordnet.NOUN
  elif tag.startswith('R'):
    return wordnet.ADV
  else:
    return wordnet.NOUN

words = word_tokenize(text)
filter_words = get_stop_words(words)
tags=pos_tag(filter_words)
lammatizer = WordNetLemmatizer()

lem = []
for word,tag in tags:
  lem.append(lammatizer.lemmatize(word, get_wordnet_pos(tag)))

pos_tagged =pos_tag(lem)
ner_tree = ne_chunk(pos_tag(lem))

nlp = spacy.load('en_core_web_sm')

doc = nlp(text)
entities = [(ent.text, ent.label_) for ent in doc.ents]
print(entities)

#grammar => {<DT>?<JJ>*<NN>} = this is a example of Noun Phrase
#grammar => {<VB.*><NP|PP>*} = this is a example of verb phrase
#grammar => {<IN><NP>} = preposition phrase

print(ner_tree)

grammar = r"""
  NP: {<DT|PP\$>?<JJ>*<NN.*>+}   # Noun Phrase: optional determiner/possessive, zero+ adjectives, one+ nouns
  PP: {<IN><NP>}                 # Prepositional Phrase: a preposition followed by a Noun Phrase
  VP: {<MD>?<VB.*><NP|PP|CLAUSE>*} # Verb Phrase: optional modal, a verb, followed by optional NPs or PPs
"""
chunk_parser = RegexpParser(grammar)
tree = chunk_parser.parse(ner_tree)
print(tree)
tree
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [('Delhi', 'GPE'), ('10000', 'MONEY')]
# (S
#   quick/JJ
#   brown/NN
#   fox/JJ
#   jump/NN
#   lazy/NN
#   dog/NN
#   young/JJ
#   studen/NN
#   (PERSON Delhi/NNP)
#   science/NN
#   competition/NN
#   10000/CD)
# (S
#   (NP quick/JJ brown/NN)
# ...
