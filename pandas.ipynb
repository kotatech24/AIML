# %% [markdown]
# <a href="https://colab.research.google.com/github/kotatech24/AIML/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s = pd.Series(["Akshat", "john", "Joseph"],
             index=[1,2,3])
print(s)
# Out:
# 1    Akshat
# 2      john
# 3    Joseph
# dtype: object

# %%
import pandas as pd
goals = pd.Series(
    [12, 8, 15, 50],
    index=["Messi", "Ronaldo", "Neymar","Mbappe"])
print(goals)
# Out:
# Messi      12
# Ronaldo     8
# Neymar     15
# Mbappe     50
# dtype: int64

# %%
goals.index.is_unique
# Out:
# True

# %%
goals["Messi"]
# Out:
# np.int64(12)

# %%
import pandas as pd
df = pd.DataFrame(
    {
    "name": ["Akshat", "Bob", "Johny"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Chennai"]
},
    index=[1,2,3]
)

print(df)
# Out:
#      name  age     city
# 1  Akshat   25    Delhi
# 2     Bob   30   Mumbai
# 3   Johny   35  Chennai

# %%
import pandas as pd
data = {
    "name": ["Akshat", "Bob", "Johny"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Chennai"]
}
df = pd.DataFrame(data, index=[1,2,3])

print(df)
# Out:
#      name  age     city
# 1  Akshat   25    Delhi
# 2     Bob   30   Mumbai
# 3   Johny   35  Chennai

# %%
import numpy as np
arr = np.array([[1,2], [3,4]])
df = pd.DataFrame(arr, columns=["A", "B"])
df
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
arr
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
df = pd.read_csv("data.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_479/3562840662.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("data.csv")
#       2 print(df)
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df = pd.read_csv("data2.csv", sep=";", usecols=["name","age"])
print(df)

# %%
df = pd.read_csv("data2.csv", sep=";", usecols=["name","age"])
df.to_excel("output.xlsx", index=False)

# %%
df1 = pd.read_excel("output.xlsx")

# %%
df = pd.read_csv("data2.csv", sep=";", usecols=["name","sex"])
excel_df = pd.read_excel("output.xlsx")
final_df = excel_df.merge(df, on="name", how="left")
final_df.to_excel("output.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_479/2236796576.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("data2.csv", sep=";", usecols=["name","sex"])
#       2 excel_df = pd.read_excel("output.xlsx")
#       3 final_df = excel_df.merge(df, on="name", how="left")
#       4 final_df.to_excel("output.xlsx", index=False)
#
# ...

# %%
df2 = pd.read_excel("output.xlsx")
print(df2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_479/2627007561.py in <cell line: 0>()
# ----> 1 df2 = pd.read_excel("output.xlsx")
#       2 print(df2)
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
#buying behaviour of the users as per there age and salary
from sklearn import tree
salary_age = [[25, 30000], [30, 40000], [35, 60000], [40,80000], [22,20000], [45,90000]]
#0 -> no (did not buy)
#1 -> yes ( purchased)
purchased = [0, 0, 1, 1, 0, 1]
model = tree.DecisionTreeClassifier()
model.fit(salary_age, purchased)
print("model is trained successfully ")
prediction = model.predict([[ 60, 95000]])
print(prediction)
# Out:
# model is trained successfully
# [1]

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
#predict the salary based on years of experience (linear regression)
x = np.array([[1], [2], [3], [4], [5]])
y = np.array([30000, 35000, 40000, 45000, 50000])  #salary
model = LinearRegression()
model.fit(x,y)
prediction = model.predict([[6]])
print(prediction)
# Out:
# [55000.]

# %%
#logistic regression -> predict pass or fail based on hours studied
from sklearn.linear_model import LogisticRegression
x = np.array([[1], [2], [3], [4], [5]])
y = np.array([0, 0, 0, 1, 1]) # 0 -> fail and 1 -> pass
model = LogisticRegression()
model.fit(x,y)
print(model.predict([[8]]))
# Out:
# [1]

# %%
#predict pass or fail using marks + attendance
from sklearn.ensemble import RandomForestClassifier
x = np.array([[35,60], [40,65], [60,80], [80, 90]])
y = np.array([0, 0, 1, 1])
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x,y)
print(model.predict([[55, 75]]))
# Out:
# [1]
